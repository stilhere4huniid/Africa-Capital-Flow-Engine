# %%
# !pip install yfinance plotly statsmodels streamlit scikit-learn openpyxl pandas numpy
# Out:
# Collecting yfinance
#   Using cached yfinance-1.0-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: plotly in c:\users\abcd\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: statsmodels in c:\users\abcd\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: streamlit in c:\users\abcd\anaconda3\lib\site-packages (1.45.1)
# Requirement already satisfied: scikit-learn in c:\users\abcd\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: openpyxl in c:\users\abcd\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: pandas in c:\users\abcd\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\abcd\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\abcd\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\abcd\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\abcd\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\abcd\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.18.3.tar.gz (3.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\abcd\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Using cached curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\abcd\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\abcd\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\abcd\anaconda3\lib\site-packages (from statsmodels) (1.11.4)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\abcd\anaconda3\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\abcd\anaconda3\lib\site-packages (from statsmodels) (23.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Collecting pillow<12,>=7.1.0 (from streamlit)
#   Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (4.13.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\abcd\anaconda3\lib\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\abcd\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abcd\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: et_xmlfile in c:\users\abcd\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abcd\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\abcd\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: jinja2 in c:\users\abcd\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\abcd\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\abcd\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\abcd\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: colorama in c:\users\abcd\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\abcd\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\abcd\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\abcd\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: six in c:\users\abcd\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abcd\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abcd\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abcd\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\abcd\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.21)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\abcd\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abcd\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\abcd\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\abcd\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\abcd\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\abcd\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Using cached yfinance-1.0-py2.py3-none-any.whl (127 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
# Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB 660.6 kB/s eta 0:00:11
#     --------------------------------------- 0.1/7.0 MB 871.5 kB/s eta 0:00:08
#     --------------------------------------- 0.1/7.0 MB 1.1 MB/s eta 0:00:07
#    - -------------------------------------- 0.2/7.0 MB 1.3 MB/s eta 0:00:06
#    -- ------------------------------------- 0.4/7.0 MB 1.5 MB/s eta 0:00:05
#    -- ------------------------------------- 0.5/7.0 MB 1.7 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/7.0 MB 1.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.8/7.0 MB 2.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.0 MB 2.3 MB/s eta 0:00:03
#    ------ --------------------------------- 1.2/7.0 MB 2.6 MB/s eta 0:00:03
#    ------- -------------------------------- 1.4/7.0 MB 2.7 MB/s eta 0:00:03
#    -------- ------------------------------- 1.5/7.0 MB 2.6 MB/s eta 0:00:03
#    --------- ------------------------------ 1.6/7.0 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.8/7.0 MB 2.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.9/7.0 MB 2.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.0 MB 2.7 MB/s eta 0:00:02
#    ------------- -------------------------- 2.3/7.0 MB 2.9 MB/s eta 0:00:02
#    ------------- -------------------------- 2.4/7.0 MB 2.8 MB/s eta 0:00:02
#    --------------- ------------------------ 2.7/7.0 MB 3.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.8/7.0 MB 3.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.9/7.0 MB 3.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.0/7.0 MB 2.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.1/7.0 MB 2.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.1/7.0 MB 2.8 MB/s eta 0:00:02
#    ------------------ --------------------- 3.2/7.0 MB 2.7 MB/s eta 0:00:02
#    ------------------ --------------------- 3.2/7.0 MB 2.7 MB/s eta 0:00:02
#    ------------------- -------------------- 3.3/7.0 MB 2.6 MB/s eta 0:00:02
#    ------------------- -------------------- 3.4/7.0 MB 2.6 MB/s eta 0:00:02
#    -------------------- ------------------- 3.6/7.0 MB 2.6 MB/s eta 0:00:02
#    --------------------- ------------------ 3.7/7.0 MB 2.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.0/7.0 MB 2.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.2/7.0 MB 2.8 MB/s eta 0:00:02
#    ------------------------- -------------- 4.5/7.0 MB 2.9 MB/s eta 0:00:01
#    --------------------------- ------------ 4.8/7.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.1/7.0 MB 3.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.0 MB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 5.3/7.0 MB 3.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.7/7.0 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/7.0 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.1/7.0 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 6.5/7.0 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 3.3 MB/s eta 0:00:00
# Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
#    ---------------------------------------- 0.0/176.8 kB ? eta -:--:--
#    ---------------------------------------  174.1/176.8 kB ? eta -:--:--
#    ---------------------------------------- 176.8/176.8 kB 3.5 MB/s eta 0:00:00
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15616 sha256=c4fb39f97efbe1352742bd19b03dc4ef4a114328e89072a21a8c53c8f2913c1b
#   Stored in directory: c:\users\abcd\appdata\local\pip\cache\wheels\42\d6\84\bf57a755f4569494cd00de4bb46ef064874823f4d19c82e960
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.3-py3-none-any.whl size=139181 sha256=670f56a4949b8993c92b607d6191cfdaef1bba62098ab3448c4c72c74706a5ef
#   Stored in directory: c:\users\abcd\appdata\local\pip\cache\wheels\05\dc\94\4ba26d23cac9aee7481d3dfcc7e99ce2cc5731230ec10f7ec1
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, websockets, pillow, curl_cffi, yfinance
#   Attempting uninstall: pillow
#     Found existing installation: pillow 12.0.0
#     Uninstalling pillow-12.0.0:
#       Successfully uninstalled pillow-12.0.0
# Successfully installed curl_cffi-0.13.0 multitasking-0.0.12 peewee-3.18.3 pillow-11.3.0 websockets-15.0.1 yfinance-1.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ABCD\anaconda3\Lib\site-packages\~il'.
#   You can safely remove it manually.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import os
import datetime

# --- CONFIGURATION ---
START_DATE = "2005-01-01"
# DYNAMIC END DATE: Always fetches data up to the current moment (Today)
END_DATE = datetime.datetime.today().strftime('%Y-%m-%d')
CONFIG_FILE = "config_countries.csv"

print(f"📡 System Start. Fetching data from {START_DATE} to {END_DATE} (Today)...")

os.makedirs('data', exist_ok=True)

# 1. LOAD COUNTRY CONFIGURATION (The "Automation" Upgrade)
print(f"Loading Country Profiles from {CONFIG_FILE}...")

try:
    if not os.path.exists(CONFIG_FILE):
        raise FileNotFoundError(f"Could not find {CONFIG_FILE}. Please create it first.")
    
    # Read CSV and convert to the exact dictionary format the engine expects
    # Expected CSV Columns: Country, Base_FDI, Oil_Sensitivity, USD_Sensitivity, Stability_Vol
    config_df = pd.read_csv(CONFIG_FILE)
    
    # Verify required columns exist
    required_cols = ['Country', 'Base_FDI', 'Oil_Sensitivity', 'USD_Sensitivity', 'Stability_Vol']
    if not all(col in config_df.columns for col in required_cols):
        raise ValueError(f"CSV is missing columns. Required: {required_cols}")

    # Transform to Dictionary: {'Nigeria': {'Base_FDI': 150, ...}, ...}
    profiles = config_df.set_index('Country').to_dict('index')
    print(f"Successfully loaded profiles for: {list(profiles.keys())}")

except Exception as e:
    print(f"CRITICAL ERROR loading config: {e}")
    print("Stopping execution. Please fix the CSV file.")
    exit()

# 2. FETCH REAL DRIVERS
print("📡 Connecting to Yahoo Finance to fetch REAL market drivers...")
tickers = ["CL=F", "DX-Y.NYB"]

try:
    # Download without selecting columns immediately
    raw_data = yf.download(tickers, start=START_DATE, end=END_DATE, interval="1mo")
    
    if raw_data.empty:
        raise ValueError("Yahoo Finance returned empty data.")

    # Smart Column Selection
    if 'Adj Close' in raw_data.columns:
        real_data = raw_data['Adj Close']
    elif 'Close' in raw_data.columns:
        print("'Adj Close' missing. Using 'Close' instead.")
        real_data = raw_data['Close']
    else:
        # Fallback
        real_data = raw_data.iloc[:, 0:2]
        real_data.columns = ['Oil_Price', 'USD_Index']

except Exception as e:
    print(f"Error processing Yahoo data: {e}")
    # Dummy Fallback
    dates = pd.date_range(start=START_DATE, end=END_DATE, freq='ME')
    real_data = pd.DataFrame(index=dates)
    real_data['Oil_Price'] = 70.0
    real_data['USD_Index'] = 100.0

if not real_data.empty:
    # Column Cleanup
    if isinstance(real_data.columns, pd.MultiIndex):
        real_data.columns = ['Oil_Price', 'USD_Index']
    else:
        # Safe mapping attempt
        if len(real_data.columns) == 2:
             real_data.columns = ['Oil_Price', 'USD_Index']

    # Fill missing data
    real_data = real_data.ffill().dropna()

    # Normalize (Z-Score)
    real_data['Oil_Norm'] = (real_data['Oil_Price'] - real_data['Oil_Price'].mean()) / real_data['Oil_Price'].std()
    real_data['USD_Norm'] = (real_data['USD_Index'] - real_data['USD_Index'].mean()) / real_data['USD_Index'].std()

    print(f"Real Data Acquired: {real_data.shape[0]} months of history.")

    # 3. GENERATE SEMI-SYNTHETIC DATASET (Using Loaded Profiles)
    all_data = []
    np.random.seed(42) 

    for country, params in profiles.items():
        # Copy the real timeline
        df = real_data.copy().reset_index()
        if 'Date' not in df.columns:
            df.rename(columns={'index': 'Date'}, inplace=True)
            
        df['Country'] = country
        
        # Generate Internal Metrics
        noise_gdp = np.random.normal(0, 1, len(df))
        df['GDP_Growth'] = 3.0 + (df['Oil_Norm'] * params['Oil_Sensitivity']) + (df['USD_Norm'] * params['USD_Sensitivity']) + noise_gdp
        
        noise_inf = np.random.normal(0, 1.5, len(df))
        base_inf = 15.0 if country in ['Nigeria', 'Egypt'] else 6.0
        df['Inflation'] = base_inf - (df['GDP_Growth'] * 0.5) + noise_inf
        df['Inflation'] = df['Inflation'].abs() 
        
        df['Interest_Rate'] = df['Inflation'] + 3.0 + np.random.normal(0, 0.5, len(df))
        
        # TARGET: FDI Inflows
        noise_fdi = np.random.normal(0, params['Base_FDI'] * 0.15, len(df))
        
        df['FDI_Inflows_MillionUSD'] = (
            params['Base_FDI'] + 
            (df['GDP_Growth'] * 20) - 
            (df['Inflation'] * 5) + 
            (df['Oil_Norm'] * params['Oil_Sensitivity'] * 50) + 
            noise_fdi
        )
        
        df['FDI_Inflows_MillionUSD'] = df['FDI_Inflows_MillionUSD'].apply(lambda x: max(x, 10))
        
        final_cols = ['Date', 'Country', 'FDI_Inflows_MillionUSD', 'GDP_Growth', 'Inflation', 'Interest_Rate', 'Oil_Price', 'USD_Index']
        all_data.append(df[final_cols])

    # Combine and Save
    final_df = pd.concat(all_data)
    final_df.to_csv("data/semi_synthetic_fdi.csv", index=False)

    print("\nSUCCESS! Dataset Generated using 'config_countries.csv'")
    print(f"Saved to: data/semi_synthetic_fdi.csv")
    
    # 4. LOGIC CHECK (Only runs if Nigeria is in the CSV)
    if 'Nigeria' in profiles:
        print("\nLOGIC CHECK: Nigeria FDI during 2014-2016 Oil Crash (Expect Drop):")
        final_df['Date'] = pd.to_datetime(final_df['Date'])
        check_nig = final_df[(final_df['Country']=='Nigeria') & (final_df['Date'].dt.year.isin([2014, 2015, 2016]))]
        print(check_nig.groupby(check_nig['Date'].dt.year)['FDI_Inflows_MillionUSD'].mean())
    else:
        print("\nSkipped Nigeria Logic Check (Nigeria not found in config file).")

else:
    print("Failed to download data. Check internet connection.")
# Out:
# 📡 System Start. Fetching data from 2005-01-01 to 2025-12-27 (Today)...
# Loading Country Profiles from config_countries.csv...
# Successfully loaded profiles for: ['Nigeria', 'Sout Africa', 'Egypt', 'Kenya']
# 📡 Connecting to Yahoo Finance to fetch REAL market drivers...
# [*********************100%***********************]  2 of 2 completed
# 'Adj Close' missing. Using 'Close' instead.
# Real Data Acquired: 252 months of history.
#
# SUCCESS! Dataset Generated using 'config_countries.csv'
# Saved to: data/semi_synthetic_fdi.csv
#
# LOGIC CHECK: Nigeria FDI during 2014-2016 Oil Crash (Expect Drop):
# Date
# 2014    220.062906
# 2015     70.153374
# 2016     53.430375
# Name: FDI_Inflows_MillionUSD, dtype: float64

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import os
import datetime

# --- CONFIGURATION ---
START_DATE = "2005-01-01"
# DYNAMIC END DATE: Always fetches data up to the current moment (Today)
END_DATE = datetime.datetime.today().strftime('%Y-%m-%d')
CONFIG_FILE = "config_countries.csv"

print(f"[INFO] System Start. Fetching data from {START_DATE} to {END_DATE} (Today)...")

os.makedirs('data', exist_ok=True)

# 1. LOAD COUNTRY CONFIGURATION
print(f"[INFO] Loading Country Profiles from {CONFIG_FILE}...")

try:
    if not os.path.exists(CONFIG_FILE):
        raise FileNotFoundError(f"Could not find {CONFIG_FILE}. Please create it first.")
    
    # Read CSV and convert to the exact dictionary format the engine expects
    config_df = pd.read_csv(CONFIG_FILE)
    
    # Verify required columns exist
    required_cols = ['Country', 'Base_FDI', 'Oil_Sensitivity', 'USD_Sensitivity', 'Stability_Vol']
    if not all(col in config_df.columns for col in required_cols):
        raise ValueError(f"CSV is missing columns. Required: {required_cols}")

    # Transform to Dictionary
    profiles = config_df.set_index('Country').to_dict('index')
    print(f"[SUCCESS] Successfully loaded profiles for: {list(profiles.keys())}")

except Exception as e:
    print(f"[CRITICAL ERROR] loading config: {e}")
    print("Stopping execution. Please fix the CSV file.")
    exit()

# 2. FETCH REAL DRIVERS
print("[INFO] Connecting to Yahoo Finance to fetch REAL market drivers...")
# CL=F: Crude Oil
# DX-Y.NYB: USD Index
# GC=F: Gold (Critical for SA/Zim)
# PL=F: Platinum (Critical for SA/Zim)
tickers = ["CL=F", "DX-Y.NYB", "GC=F", "PL=F"]

try:
    # Download data
    raw_data = yf.download(tickers, start=START_DATE, end=END_DATE, interval="1mo", progress=False)
    
    if raw_data.empty:
        raise ValueError("Yahoo Finance returned empty data.")

    # Smart Column Selection
    if 'Adj Close' in raw_data.columns:
        real_data = raw_data['Adj Close'].copy()
    elif 'Close' in raw_data.columns:
        print("[WARN] 'Adj Close' missing. Using 'Close' instead.")
        real_data = raw_data['Close'].copy()
    else:
        # Fallback
        real_data = raw_data.iloc[:, :4].copy()
        real_data.columns = ['Oil_Price', 'USD_Index', 'Gold_Price', 'Platinum_Price']

except Exception as e:
    print(f"[ERROR] Error processing Yahoo data: {e}")
    # Dummy Fallback
    dates = pd.date_range(start=START_DATE, end=END_DATE, freq='ME')
    real_data = pd.DataFrame(index=dates)
    real_data['Oil_Price'] = 70.0
    real_data['USD_Index'] = 100.0
    real_data['Gold_Price'] = 1800.0
    real_data['Platinum_Price'] = 900.0

if not real_data.empty:
    # --- RENAME COLUMNS STANDARDIZATION ---
    # Ensure columns map correctly. Yahoo sorts alphabetically: CL=F, DX-Y.NYB, GC=F, PL=F
    rename_map = {
        'CL=F': 'Oil_Price',
        'DX-Y.NYB': 'USD_Index',
        'GC=F': 'Gold_Price',
        'PL=F': 'Platinum_Price'
    }
    
    # If columns match tickers (usual case), rename them
    real_data.rename(columns=rename_map, inplace=True)
    
    # Safety Check: If renaming didn't work (unexpected format), force rename by position if 4 cols exist
    if 'Oil_Price' not in real_data.columns and real_data.shape[1] == 4:
         real_data.columns = ['Oil_Price', 'USD_Index', 'Gold_Price', 'Platinum_Price']

    # Fill missing data
    real_data = real_data.ffill().dropna()

    # --- NORMALIZE (Z-Score) ---
    # We use explicit names here so we know exactly what to call in the formula
    for col in ['Oil_Price', 'USD_Index', 'Gold_Price', 'Platinum_Price']:
        if col in real_data.columns:
            real_data[f'{col}_Norm'] = (real_data[col] - real_data[col].mean()) / real_data[col].std()

    print(f"[SUCCESS] Real Data Acquired (Oil, USD, Gold, Platinum): {real_data.shape[0]} months.")

    # 3. GENERATE SEMI-SYNTHETIC DATASET
    all_data = []
    np.random.seed(42) 

    for country, params in profiles.items():
        # Copy the real timeline
        df = real_data.copy().reset_index()
        if 'Date' not in df.columns:
            df.rename(columns={'index': 'Date'}, inplace=True)
            
        df['Country'] = country
        
        # --- GDP LOGIC (UPDATED VARIABLE NAMES) ---
        
        if country in ['South Africa', 'Zimbabwe']:
             # Economy grows when Minerals are high (Gold & Platinum)
             # Note: Using 'Gold_Price_Norm' instead of 'Gold_Norm' to match column creation above
             impact = (df['Gold_Price_Norm'] * 0.4) + (df['Platinum_Price_Norm'] * 0.4)
        else:
             # Standard Model: Economy grows based on Oil Sensitivity
             # Note: Using 'Oil_Price_Norm' instead of 'Oil_Norm'
             impact = (df['Oil_Price_Norm'] * params['Oil_Sensitivity'])

        # GDP Calculation
        # Note: Using 'USD_Index_Norm' instead of 'USD_Norm'
        noise_gdp = np.random.normal(0, 1, len(df))
        df['GDP_Growth'] = 3.0 + impact + (df['USD_Index_Norm'] * params['USD_Sensitivity']) + noise_gdp
        
        # Inflation Calculation
        noise_inf = np.random.normal(0, 1.5, len(df))
        base_inf = 15.0 if country in ['Nigeria', 'Egypt'] else 6.0
        df['Inflation'] = base_inf - (df['GDP_Growth'] * 0.5) + noise_inf
        df['Inflation'] = df['Inflation'].abs() 
        
        df['Interest_Rate'] = df['Inflation'] + 3.0 + np.random.normal(0, 0.5, len(df))
        
        # TARGET: FDI Inflows
        noise_fdi = np.random.normal(0, params['Base_FDI'] * 0.15, len(df))
        
        # We use 'Oil_Price_Norm' here for global sentiment in FDI formula
        df['FDI_Inflows_MillionUSD'] = (
            params['Base_FDI'] + 
            (df['GDP_Growth'] * 20) - 
            (df['Inflation'] * 5) + 
            (df['Oil_Price_Norm'] * params['Oil_Sensitivity'] * 50) + 
            noise_fdi
        )
        
        df['FDI_Inflows_MillionUSD'] = df['FDI_Inflows_MillionUSD'].apply(lambda x: max(x, 10))
        
        # Select Columns (Include new minerals)
        final_cols = ['Date', 'Country', 'FDI_Inflows_MillionUSD', 'GDP_Growth', 'Inflation', 'Interest_Rate', 'Oil_Price', 'USD_Index', 'Gold_Price', 'Platinum_Price']
        
        # Only keep columns that actually exist (Safety)
        final_cols = [c for c in final_cols if c in df.columns]
        
        all_data.append(df[final_cols])

    # Combine and Save
    final_df = pd.concat(all_data)
    final_df.to_csv("data/semi_synthetic_fdi.csv", index=False)

    print("\n[SUCCESS] Dataset Generated using 'config_countries.csv'")
    print(f"Saved to: data/semi_synthetic_fdi.csv")

else:
    print("[FAIL] Failed to download data. Check internet connection.")
# Out:
# [INFO] System Start. Fetching data from 2005-01-01 to 2025-12-27 (Today)...
# [INFO] Loading Country Profiles from config_countries.csv...
# [SUCCESS] Successfully loaded profiles for: ['Nigeria', 'South Africa', 'Egypt', 'Kenya']
# [INFO] Connecting to Yahoo Finance to fetch REAL market drivers...
# [WARN] 'Adj Close' missing. Using 'Close' instead.
# [SUCCESS] Real Data Acquired (Oil, USD, Gold, Platinum): 252 months.
#
# [SUCCESS] Dataset Generated using 'config_countries.csv'
# Saved to: data/semi_synthetic_fdi.csv
